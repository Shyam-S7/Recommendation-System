# %%
import pandas as pd

# %%
df = pd.read_csv("D:\PROJECTS\ML\Recommendation-System\preprocessed.csv")
df.head()
# Out:
#                                                 name  \
# 0  Ethnic Motifs Printed Kurta with Palazzos  Wit...
# 1    Solid Kurta with Palazzos  Floral Print Dupatta
# 2  Ethnic Motifs Embroidered Thread Work Kurta wi...
# 3         Floral Printed Kurta With Trouser  Dupatta
# 4                             Printed Straight Kurta
#
#                                                  img  \
# 0  http://assets.myntassets.com/assets/images/170...
# 1  http://assets.myntassets.com/assets/images/165...
# 2  http://assets.myntassets.com/assets/images/163...
# 3  http://assets.myntassets.com/assets/images/147...
# 4  http://assets.myntassets.com/assets/images/110...
#
#                                                 tags
# 0  ['khushal', 'k', 'black', 'printed', 'kurta', ...
# 1  ['inweave', 'orange', 'solid', 'kurta', 'palaz...
# 2  ['anubhutee', 'navy', 'blue', 'embroidered', '...
# 3  ['nayo', 'red', 'printed', 'kurta', 'trouser',...
# 4  ['ahika', 'black', 'green', 'printed', 'straig...

# %%
print(df["tags"][0])
# Out:
# ['khushal', 'k', 'black', 'printed', 'kurta', 'palazzos', 'dupatta', 'design', 'ethnic', 'motif', 'anarkali', 'shape', 'regular', 'style', 'mandarin', 'collar', 'threequarter', 'sleeve', 'calf', 'length', 'flared', 'hem', 'viscose', 'rayon', 'machine', 'weave', 'fabric', 'elasticated', 'waistband', 'slipon', 'closure', 'meter', 'widthnbsp', 'cmthe', 'model', 'height', 'wearing', 'size', 'rayonmachine', 'wash', 'na', 'garment', 'measurement', 'solid', 'indie', 'print', 'festive', 'placement', 'ready', 'wear', 'screen']
